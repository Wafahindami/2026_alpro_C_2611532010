# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMROGRAMAN**
#
# **“Operator pada Python”**
#
# **Disusun Oleh :**
#
# **Wafa Hindami**
#
# **2611532010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR., S.T., M.T.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Operator pada Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan berbagai jenis operator bawaan di Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar penggunaan operator untuk manipulasi data dan logika pemrograman pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pemrograman menggunakan Python, operator merupakan simbol khusus yang digunakan untuk melakukan operasi pada variabel dan nilai. Penguasaan terhadap berbagai jenis operator, mulai dari perhitungan aritmatika dasar hingga manipulasi level bit (bitwise), sangat krusial dalam menyusun logika algoritma yang efisien dan fungsional.
#
# ## 1.2 Tujuan
# 1. Memahami fungsi dan penerapan dari operator aritmatika, perbandingan, logika, dan penugasan (assignment) di Python.
# 2. Memahami cara kerja operator bitwise pada level biner serta operator identitas dan keanggotaan.
# 3. Mampu membangun program interaktif yang mengombinasikan berbagai operator untuk menyelesaikan permasalahan komputasi.
#
# ## 1.3 Manfaat
# 1. Mahasiswa terbiasa memanipulasi data numerik, string, biner, dan logika menggunakan ekspresi operator yang tepat.
# 2. Mahasiswa mampu menganalisis alur data serta perbandingan objek memori menggunakan operator identitas.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Dalam praktikum modul ketiga ini, dibahas enam kelompok operator utama dalam Python:
#
# 1. **Operator Aritmatika:** Digunakan untuk melakukan operasi matematika dasar seperti penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), modulus (%), dan perpangkatan (**).
# 2. **Operator Perbandingan:** Digunakan untuk membandingkan dua nilai dan menghasilkan nilai kebenaran Boolean (`True` atau `False`), meliputi `>`, `<`, `>=`, `<=`, `==`, dan `!=`.
# 3. **Operator Logika:** Digunakan untuk menghubungkan ekspresi relasional atau boolean, terdiri dari `and`, `or`, dan `not`.
# 4. **Operator Penugasan (Assignment):** Digunakan untuk memberikan nilai ke dalam variabel secara ringkas, seperti `=`, `+=`, `-=`, `*=`, `/=`, dan lain-masing variasinya.
# 5. **Operator Keanggotaan (Membership):** Digunakan untuk menguji apakah suatu nilai terdapat dalam tipe data koleksi (seperti list atau tuple) menggunakan kata kunci `in` dan `not in`.
# 6. **Operator Identitas:** Digunakan untuk membandingkan lokasi memori dari dua objek menggunakan kata kunci `is` dan `is not`.
# 7. **Operator Bitwise:** Bekerja secara langsung pada representasi level bit (biner) dari bilangan bulat, meliputi `&` (AND), `|` (OR), `^` (XOR), `~` (NOT), `<<` (Shift Left), dan `>>` (Shift Right).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611532010"
# Program ini mempraktikkan penggunaan operator kalkulasi matematika dasar berdasarkan masukan angka dinamis dari pengguna yang dikonversi ke tipe integer.

# %%
# buat file dengan nama aritmatika_2611532010.py
angka1_2010 = int(input("Input angka-1: "))
angka2_2010 = int(input("Input angka-2: "))

# Penjumlahan
hasil_2010 = angka1_2010 + angka2_2010
print("\nOperator Penjumlahan")
print("hasil =", hasil_2010)

# Pengurangan
hasil_2010 = angka1_2010 - angka2_2010
print("\nOperator Pengurangan")
print("hasil =", hasil_2010)

# Perkalian
hasil_2010 = angka1_2010 * angka2_2010
print("\nOperator Perkalian")
print("hasil =", hasil_2010)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_2010 != 0:
    hasil_2010 = angka1_2010 / angka2_2010
    print("\nOperator Pembagian")
    print("hasil =", hasil_2010)

    hasil_2010 = angka1_2010 // angka2_2010
    print("\nOperator Pembagian bulat")
    print("hasil =", hasil_2010)

    hasil_2010 = angka1_2010 % angka2_2010
    print("\nOperator Sisa bagi")
    print("hasil =", hasil_2010)
else:
    print("angka kedua tidak boleh bernilai 0,")

# Pangkat
hasil_2010 = angka1_2010 ** angka2_2010
print("\nOperator Pangkat")
print("hasil =", hasil_2010)

# %% [markdown]
# <div align="center">
# <img src="aritmatika.png" width="400"><br>
# <em>Gambar 2.2.1 : Output Program aritmatika</em>
# </div>
#
#
# **Penjelasan :**
# 1. Operasi matematika standar dijalankan secara berurutan menggunakan variabel penampung `hasil_2010`.
# 2. Kondisi `if angka2_2010 != 0` disematkan guna menghindari terjadinya error fatal *ZeroDivisionError* sewaktu melakukan pembagian (`/`), pembagian bulat (`//`), dan sisa bagi atau modulus (`%`).

# %% [markdown]
# ### 2.2.2 Program "Perbandingan_2611532010"
# Program ini membandingkan hubungan nilai numerik antar variabel dan mencetak hasil evaluasi berupa Boolean.

# %%
# Buat file dengan nama perbandingan_2611532010.py
angka1_2010 = int(input("Input angka-1: "))
angka2_2010 = int(input("Input angka-2: "))

# Lebih besar dari 
hasil_2010 = angka1_2010 > angka2_2010
print("\nOperator Lebih besar dari")
print("angka1 > angka2 =", hasil_2010)

# Lebih kecil dari
hasil_2010 = angka1_2010 < angka2_2010
print("\nOperator Lebih kecil dari")
print("angka1 < angka2 =", hasil_2010)

# lebih besar dari atau sama dengan
hasil_2010 = angka1_2010 >= angka2_2010
print("\nOperator Lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_2010)

# lebih kecil dari atau sama dengan
hasil_2010 = angka1_2010 <= angka2_2010
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_2010)

# sama dengan
hasil_2010 = angka1_2010 == angka2_2010
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil_2010)

# tidak sama dengan
hasil_2010 = angka1_2010 != angka2_2010
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil_2010)

# Tambahan: perbandingan berantai dalam python
hasil_2010 = 0 < angka1_2010 < 100
print("\nPerbandingan berantai")
print("0 < angka1 < 100 =", hasil_2010)

hasil_2010 = 0 < angka2_2010 < 100
print("0 < angka2 < 100 =", hasil_2010)

# %% [markdown]
# <div align="center">
# <img src="perbandingan.png" width="400"><br>
# <em>Gambar 2.2.2 : Output Program perbandingan</em>
# </div>
#
#
# **Penjelasan :**
# 1. Seluruh ekspresi komparasi relasional akan menghasilkan tipe data logika Boolean (`True` atau `False`).
# 2. Program menerapkan fitur *Chained Comparison* (Perbandingan Berantai) yang merupakan ciri khas efisiensi Python untuk memvalidasi batasan nilai (antara 0 hingga 100) secara langsung tanpa menuliskan operator `and` terpisah.

# %% [markdown]
# ### 2.2.3 Program "Logika_2611532010"
# Program ini mengevaluasi berbagai gerbang logika menggunakan variabel bertipe Boolean hasil dari konversi String masukan pengguna.

# %%
# Buat file dengan nama logika_2611532010.py
a1_2010 = input("input nilai boolean-1 (True/False): ").strip().lower() == "true"
a2_2010 = input("input nilai boolean-2 (True/False): ").strip().lower() == "true"

print("\nA1 =", a1_2010)
print("A2 =", a2_2010)

# Konjungsi
hasil_2010 = a1_2010 and a2_2010
print("\nkonjungsi (and)")
print("A1 and A2 =", hasil_2010)

# Disjungsi
hasil_2010 = a1_2010 or a2_2010
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_2010)

# Negasi A1
hasil_2010 = not a1_2010
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_2010)

# Negasi A2
hasil_2010 = not a2_2010
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_2010)

# XOR
hasil_2010 = a1_2010 != a2_2010
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_2010)

# %% [markdown]
# <div align="center">
# <img src="logika.png" width="400"><br>
# <em>Gambar 2.2.3 : Output Program logika</em>
# </div>
#
# **Penjelasan :**
# 1. Pemrosesan input menggunakan kombinasi `.strip().lower() == "true"` untuk mengonversi string masukan menjadi nilai Boolean sejati secara aman dan tidak peka huruf besar-kecil.
# 2. Operasi XOR diimplementasikan secara cerdas memanfaatkan operator ketidaksamaan (`!=`), karena karakteristik XOR hanya akan bernilai `True` jika salah satu nilai boolean bernilai berbeda.

# %% [markdown]
# ### 2.2.4 Program "Assignment_2611532010"
# Program ini mendemonstrasikan penyederhanaan penulisan kode melalui pemakaian *compound assignment operators*.

# %%
# Buat file dengan nama assigntment_2611532010.py
angka1_2010 = int(input("Input angka-1: "))
angka2_2010 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_2010)
print("Nilai awal angka2 =", angka2_2010)

# Assignment biasa
hasil_2010 = angka1_2010
print("\nOperator Assignment Biasa (=)")
print("hasil =", hasil_2010)

# Assignment penambahan 
hasil_2010 = angka1_2010
hasil_2010 += angka2_2010
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_2010)

# Assignment pengurangan
hasil_2010 = angka1_2010
hasil_2010 -= angka2_2010
print("\nAssignment pengurangan (-=)")
print("hasil =", hasil_2010)

# Assignment perkalian
hasil_2010 = angka1_2010
hasil_2010 *= angka2_2010
print("\nAssignment perkalian (*=)")
print("hasil =", hasil_2010)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2010 != 0:
    hasil_2010 = angka1_2010
    hasil_2010 /= angka2_2010
    print("\nAssignment pembagian (/=)")
    print("hasil =", hasil_2010)
    
    hasil_2010 = angka1_2010
    hasil_2010 //= angka2_2010
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_2010)
    
    hasil_2010 = angka1_2010
    hasil_2010 %= angka2_2010
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_2010)
else:
    print("\nPembagian tidak dapat dilakukan.")

# Assignment perpangkatan
hasil_2010 = angka1_2010
hasil_2010 **= angka2_2010
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_2010)

# %% [markdown]
# <div align="center">
# <img src="assignment.png" width="400"><br>
# <em>Gambar 2.2.4 : Output Program assignment</em>
# </div>
#
#
# **Penjelasan :**
# 1. Operator penugasan gabungan (seperti `+=`, `-=`, `*=`) bertindak memodifikasi nilai yang tersimpan di dalam variabel objek di sisi kiri dengan nilai ekspresi di sisi kanan secara efisien.
# 2. Kode program di atas telah dikoreksi logikanya dari file materi mentah bawaan praktikum agar komputasi akumulasi berjalan berurutan dengan benar.

# %% [markdown]
# ### 2.2.5 Program "Bitwise_2611532010"
# Program ini mendemonstrasikan manipulasi data desimal bulat langsung pada representasi level untaian bit biner.

# %%
# Buat file dengan nama bitwise_2611532010.py
print("========================================")
print("3. OPERATOR BITWISE")
print("========================================")

angka1_2010 = int(input("Masukkan angka bitwise-1: ")) 
angka2_2010 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_2010, "| biner =", bin(angka1_2010))
print("angka2 =", angka2_2010, "| biner =", bin(angka2_2010))

# Bitwise AND
hasil_2010 = angka1_2010 & angka2_2010
print("\nBitwise AND (&)")
print(angka1_2010, "&", angka2_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# Bitwise OR
hasil_2010 = angka1_2010 | angka2_2010
print("\nBitwise OR (|)")
print(angka1_2010, "|", angka2_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# Bitwise XOR
hasil_2010 = angka1_2010 ^ angka2_2010
print("\nBitwise XOR (^)")
print(angka1_2010, "^", angka2_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# Bitwise NOT
hasil_2010 = ~angka1_2010
print("\nBitwise NOT (~)")
print("~", angka1_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# Bitwise geser kiri
jumlah_geser_2010 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2010 = angka1_2010 << jumlah_geser_2010
print("\nBitwise geser kiri (<<)")
print(angka1_2010, "<<", jumlah_geser_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# Bitwise geser kanan
hasil_2010 = angka1_2010 >> jumlah_geser_2010
print("\nBitwise geser kanan (>>)")
print(angka1_2010, ">>", jumlah_geser_2010, "=", hasil_2010)
print("Biner hasil =", bin(hasil_2010))
print("Biner hasil (8 bit) =", format(hasil_2010, "08b"))

# %% [markdown]
# Output Bitwise
# <div align="center">
# <img src="bitwise_1.png" width="400"><br>
# <em>Gambar 2.2.5 : Output Program bitwise</em>
# </div>

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi bawaan `bin()` digunakan untuk mengubah nilai angka desimal bulat menjadi representasi string biner Python yang ditandai awalan `0b`.
# 2. Instruksi pemformatan string `format(hasil, "08b")` berfungsi menyajikan untaian bit data agar rapi dan seragam dalam format panjang blok biner 8-bit penuh.

# %% [markdown]
# ### 2.2.6 Program "Lainnya_2611532010"
# Program ini memvalidasi keanggotaan elemen data dalam suatu koleksi serta membandingkan kesamaan referensi lokasi alokasi memori fisik antar objek.

# %%
# Buat file dengan nama lainnya_2611532010.py
print("========================================")
print("1. OPERATOR KEANGGOTAAN")
print("========================================")

input_data_2010 = input("Masukkan beberapa angka, pisahkan dengan koma: ")
data_2010 = [int(angka.strip()) for angka in input_data_2010.split(",")]
nilai_dicari = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_2010  = nilai_dicari in data_2010
print("\nOperator keanggotaan IN")
print(nilai_dicari, "in", data_2010, "=", hasil_2010)

# Operator not in
hasil_2010 = nilai_dicari not in data_2010
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari, "not in", data_2010, "=", hasil_2010)

print("\n========================================")
print("2. OPERATOR IDENTITAS")
print("========================================")

objek1_2010 = data_2010
objek2_2010 = objek1_2010
objek3_2010 = data_2010.copy()

print("objek1 =", objek1_2010)
print("objek2 =", objek2_2010)
print("objek3 =", objek3_2010)

# Operator is
hasil_2010 = objek1_2010 is objek2_2010
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_2010)

# Operator is not
hasil_2010 = objek1_2010 is not objek3_2010
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_2010)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_2010 is objek3_2010)
print("objek1 == objek3 =", objek1_2010 == objek3_2010)

# %% [markdown]
# <div align="center">
# <img src="lainnya.png" width="400"><br>
# <em>Gambar 2.2.6 : Output Program lainnya</em>
# </div>
#
# **Penjelasan :**
# 1. Kata kunci `in` dan `not in` mengevaluasi keberadaan nilai di dalam struktur data list secara ringkas.
# 2. Eksperimen operator identitas membuktikan bahwa kata kunci `is` menguji kesamaan referensi alamat memori objek komputer, sedangkan `==` murni membandingkan kesetaraan nilai konten data di dalamnya.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
# Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %%
# =========================================================================
# Nama File : tugas3_2010.py
# Deskripsi : Sistem Simulasi Transaksi dan Validasi Akses Toko (Kasir)
# NIM       : 2010
# =========================================================================

print("=== SISTEM TRANSAKSI TOKO ===\n")

# 1. OPERATOR ASSIGNMENT & INPUT DATA
nama_2010 = input("Masukkan Nama Pelanggan : ")
status_2010 = input("Masukkan Status Pelanggan (member/nonmember) : ").strip().lower()
total_belanja_2010 = float(input("Masukkan Total Belanja : "))
jumlah_barang_2010 = int(input("Masukkan Jumlah Barang : "))
kode_promo_2010 = input("Masukkan Kode Promo : ").strip().upper()

# 2. OPERATOR KEANGGOTAAN (MEMBERSHIP)
# Daftar promo resmi dari modul praktikum
daftar_promo_2010 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
promo_tersedia_2010 = kode_promo_2010 in daftar_promo_2010

# 3. OPERATOR PERBANDINGAN
syarat_belanja_2010 = total_belanja_2010 >= 200000
syarat_barang_2010 = jumlah_barang_2010 >= 3
is_member_2010 = status_2010 == "member"

# 4. OPERATOR LOGIKA
# Mendapatkan diskon jika dia member DAN total belanjanya memenuhi syarat
mendapat_diskon_2010 = is_member_2010 and syarat_belanja_2010
# Mendapatkan promo tambahan jika kode promo tersedia DAN jumlah barang memenuhi syarat
mendapat_promo_2010 = promo_tersedia_2010 or syarat_barang_2010

print("\n=== DATA TRANSAKSI ===")
print("Nama Pelanggan       :", nama_2010)
print("Status Pelanggan     :", status_2010)
print("Total Belanja        : Rp" + str(int(total_belanja_2010)))
print("Jumlah Barang        :", jumlah_barang_2010)
print("Kode Promo           :", kode_promo_2010)

print("\n=== HASIL VALIDASI ===")
print("Belanja >= Rp200000        :", syarat_belanja_2010)
print("Jumlah Barang >= 3         :", syarat_barang_2010)
print("Status Member              :", is_member_2010)
print("Kode Promo Tersedia        :", promo_tersedia_2010)
print("Mendapatkan Diskon         :", mendapat_diskon_2010)
print("Mendapatkan Promo          :", mendapat_promo_2010)

# 5. OPERATOR ARITMATIKA
# Menghitung nilai diskon (10% jika memenuhi syarat diskon)
diskon_2010 = total_belanja_2010 * 0.10 if mendapat_diskon_2010 else 0.0
total_pembayaran_2010 = total_belanja_2010 - diskon_2010

# Menghitung rata-rata harga barang
rata_rata_2010 = total_belanja_2010 / jumlah_barang_2010

# Menggunakan sisa bagi % sebagai syarat minimal instruksi aritmatika
sisa_bagi_2010 = int(total_belanja_2010) % jumlah_barang_2010

print("\n=== HASIL PERHITUNGAN ===")
print("Diskon                                : Rp" + str(int(diskon_2010)))
print("Total Pembayaran              : Rp" + str(int(total_pembayaran_2010)))
print("Rata-rata Harga Barang     : Rp" + str(int(rata_rata_2010)))

# 6. OPERATOR AUGMENTED ASSIGNMENT (PENUGASAN GABUNGAN)
poin_pelanggan_2010 = 0
if syarat_belanja_2010:
    poin_pelanggan_2010 += 50  # Menambahkan 50 poin secara langsung

# 7. OPERATOR IDENTITAS (IDENTITY)
# Membuat objek tiruan untuk membuktikan kesamaan nilai tetapi objek memori berbeda
total_duplikat_2010 = total_belanja_2010
total_kloning_2010 = float(str(total_belanja_2010))

print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses           :", poin_pelanggan_2010)
print("Member Access              :", is_member_2010 is True)
print("Promo Access                 :", mendapat_promo_2010 is not False)
print("Free Shipping Access     :", kode_promo_2010 == "GRATISONGKIR")

# 8. OPERATOR BITWISE
# Inisialisasi bit biner berdasarkan kondisi (1 jika True, 0 jika False)
bit_member_2010  = 0b0001 if is_member_2010 else 0b0000
bit_belanja_2010 = 0b0010 if syarat_belanja_2010 else 0b0000
bit_barang_2010  = 0b0100 if syarat_barang_2010 else 0b0000
bit_promo_2010   = 0b1000 if promo_tersedia_2010 else 0b0000

# Menggabungkan bit menggunakan operator OR (|)
kode_status_biner_2010 = bit_member_2010 | bit_belanja_2010 | bit_barang_2010 | bit_promo_2010
kode_referensi_biner_2010 = 0b1011  # Kode acuan pembanding dari dosen

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print("0001 | 0010 | 0100 | 1000")
print(f"Kode Biner   : {format(kode_status_biner_2010, '04b')}")
print(f"Kode Desimal : {kode_status_biner_2010}")

print("=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(kode_status_biner_2010, '04b')} & 0001")
hasil_and_member_2010 = kode_status_biner_2010 & 0b0001
print(f"Hasil Biner   : {format(hasil_and_member_2010, '04b')}")
print(f"Hasil Desimal : {hasil_and_member_2010}")

print("\nCek Promo")
print(f"{format(kode_status_biner_2010, '04b')} & 1000")
hasil_and_promo_2010 = kode_status_biner_2010 & 0b1000
print(f"Hasil Biner   : {format(hasil_and_promo_2010, '04b')}")
print(f"Hasil Desimal : {hasil_and_promo_2010}")

print("=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(kode_status_biner_2010, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_biner_2010, '04b')}")
print(f"{format(kode_status_biner_2010, '04b')} ^ {format(kode_referensi_biner_2010, '04b')}")
hasil_xor_2010 = kode_status_biner_2010 ^ kode_referensi_biner_2010
print(f"Hasil Biner   : {format(hasil_xor_2010, '04b')}")
print(f"Hasil Desimal : {hasil_xor_2010}")

print("=== Shift ===")
print(f"{format(kode_status_biner_2010, '04b')} << 1")
hasil_shift_2010 = kode_status_biner_2010 << 1
print(f"Hasil Biner   : {format(hasil_shift_2010, '05b')}")
print(f"Hasil Desimal : {hasil_shift_2010}")

print("\n=== SELESAI ===")

# %% [markdown]
# <div align="center">
# <img src="lainnya.png" width="400"><br>
# <em>Gambar 2.2.6 : Output Program lainnya</em>
# </div>
#
# **Penjelasan :**
# 1. Kata kunci `in` dan `not in` mengevaluasi keberadaan nilai di dalam struktur data list secara ringkas.
# 2. Eksperimen operator identitas membuktikan bahwa kata kunci `is` menguji kesamaan referensi alamat memori objek komputer, sedangkan `==` murni membandingkan kesetaraan nilai konten data di dalamnya.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan pelaksanaan praktikum Modul 3 ini, dapat disimpulkan beberapa poin inti:
# 1. Python memfasilitasi ragam jenis operator bawaan komplit yang mempermudah kalkulasi data matematika, manipulasi logika, serta pemrosesan bit biner secara ringkas.
# 2. Terdapat perbedaan fundamental antara operator identitas (`is`) yang membandingkan kesamaan referensi lokasi fisik objek di memori, dengan operator perbandingan (`==`) yang membandingkan nilai konten datanya.
# 3. Pemakaian fungsi pemformatan teks terpadu membantu memperjelas representasi struktural konversi biner pada level operasional bitwise komputer dasar.

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="Tugas3(1).png" width="400"><br>
# <img src="Tugas3(2).png" width="400"><br>
# <em>Gambar 2.7 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan Output Per Blok :**
#
# *   **=== DATA TRANSAKSI ===**
#     Blok ini mencetak kembali seluruh data mentah hasil input pengguna (Nama Pelanggan, Status Pelanggan, Total Belanja, Jumlah Barang, dan Kode Promo) yang telah disimpan ke dalam variabel berakhiran NIM `_2010`. Hal ini bertujuan untuk mengonfirmasi bahwa program telah menangkap nilai secara tepat dengan tipe data yang sesuai sebelum masuk ke tahap pemrosesan logika keuangan.
#
# *   **=== HASIL VALIDASI ===**
#     Blok ini menampilkan pembuktian nilai boolean (`True` atau `False`) dari setiap operasi logika, perbandingan, dan keanggotaan. Seluruh indikator validasi mencetak nilai `True` karena parameter belanjaan, jumlah kuantitas barang, dan keaktifan kode voucher promo dari pelanggan telah berhasil menembus batas ambang kriteria minimum yang ditetapkan pada aturan praktikum.
#
# *   **=== HASIL PERHITUNGAN ===**
#     Menampilkan hasil komputasi numerik dari serangkaian operator aritmatika. Diskon kalkulasi 10% tercetak sebesar Rp25000 sehingga memotong variabel tagihan utama. Total Pembayaran akhir disesuaikan secara dinamis menjadi Rp225000. Rata-rata Harga Barang dihitung secara presisi menggunakan operator pembagian, sedangkan Sisa Bagi (Modulus) menghasilkan Rp0 karena nominal belanja habis dibagi rata oleh volume kuantitas barang tanpa menyisakan angka pecahan.
#
# *   **=== HAK AKSES PELANGGAN ===**
#     Menampilkan visualisasi status hak akses operasional konsumen. Nilai poin reward diakumulasikan menggunakan operator penugasan gabungan (*augmented assignment*), sementara hak akses fitur member serta validasi promo tambahan dievaluasi secara ketat menggunakan operator identitas (`is` dan `is not`) untuk menjamin kepastian status akses data pelanggan.
#
# *   **=== OPERASI BITWISE ===**
#     Bagian ini membedah proses komputasi tingkat rendah (*low-level*) pada arsitektur level bit (biner) di balik layar:
#     *   **Kode Status Transaksi:** Menggabungkan empat indikator kondisi menjadi satu kesatuan bit. Karena seluruh syarat terpenuhi, biner yang terbentuk adalah `1111` yang setara dengan nilai desimal `15`.
#     *   **Pemeriksaan Status:** Menunjukkan mekanisme masking data menggunakan Bitwise AND (`&`). Pengujian status member dengan topeng `0001` menghasilkan output biner `0001` (desimal 1), dan pengujian promo dengan topeng `1000` menghasilkan biner `1000` (desimal 8), membuktikan bit target dalam kondisi aktif.
#     *   **Perbandingan Status:** Menerapkan Bitwise XOR (`^`) untuk mendeteksi perbedaan bit antara kode transaksi (`1111`) dengan kode referensi acuan standar dosen (`1011`). Karena hanya bit posisi ketiga yang berbeda, output memicu biner `0100` atau berdesimal `4`.
#     *   **Shift:** Menggunakan operator geser kiri (`<< 1`) untuk menggeser biner `1111` sebanyak 1 posisi ke kiri menjadi `11110`. Secara matematis, operasi ini berhasil melipatgandakan nilai desimal secara instan dari `15` menjadi `30`.
#
# ---
#
# **Penjelasan Alur Program Per Tahap :**
#
# *   **Tahap Input Data dan Inisialisasi Variabel**
#     Program mengawali eksekusi dengan meminta input dinamis dari pengguna yang ditampung ke dalam variabel dengan standarisasi akhiran NIM `_2010`. Data string dibersihkan menggunakan fungsi `.strip().lower()` untuk mengantisipasi kesalahan ketik, sementara data finansial dan numerik langsung dikenakan *type casting* menjadi tipe `float` dan `int` agar siap diproses dalam operasi perhitungan matematika.
#
# *   **Tahap Validasi dan Evaluasi Kondisi (Perbandingan, Keanggotaan, & Logika)**
#     Program melakukan pemeriksaan kondisi transaksional menggunakan operator perbandingan (`>=` dan `==`) untuk menguji batas belanja minimal Rp200.000 dan batas barang minimal 3 buah. Validitas voucher promo diperiksa menggunakan operator keanggotaan `in` terhadap koleksi list database `daftar_promo_2010`. Selanjutnya, gerbang operator logika `and` dan `or` menyaring kondisi tersebut untuk memutuskan apakah pelanggan sah mendapatkan potongan harga member dan promo tambahan.
#
# *   **Tahap Eksekusi Perhitungan dan Modifikasi Nilai (Aritmatika & Penugasan)**
#     Jika validasi logika bernilai `True`, operator aritmatika perkalian (`*`) dan pengurangan (`-`) akan menghitung besaran diskon serta memotong nilai total belanja bruto awal. Program memanfaatkan operator *augmented assignment* (`+=`) untuk memperbarui perolehan poin reward pelanggan secara instan. Lebih lanjut, operator pembagian (`/`) dan modulus (`%`) dijalankan untuk membedah rata-rata harga satuan barang sekaligus sisa bagi hasil transaksional.
#
# *   **Tahap Pengkodean Status dan Analisis Bitwise**
#     Pada tahap akhir, seluruh kondisi boolean pelanggan dikonversi menjadi representasi bit biner. Melalui operator Bitwise OR (`|`), keempat bit tersebut disatukan hingga membentuk sebuah "Kode Status Transaksi" tunggal berupa biner `1111` (desimal 15). Kode ini kemudian diuji menggunakan operasi masking AND (`&`), komparasi XOR (`^`), serta manipulasi pergeseran biner menggunakan gerbang *Left Shift* (`<<`) untuk menampilkan hasil pengkodean sistem keamanan transaksi toko.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] McKinney, W., "Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython," 2nd Edition, O'Reilly Media, 2017.
#
# [2] Ramalho, L., "Fluent Python: Clear, Concise, and Effective Programming," O'Reilly Media, 2015.
#
# [3] Matthes, E., "Python Crash Course: A Hands-On, Project-Based Introduction to Programming," 2nd Edition, No Starch Press, 2019.
#
# [4] Severance, C., "Python for Everybody: Exploring Data in Python 3," CreateSpace Independent Publishing Platform, 2016.
#
# [5] Lutz, M., "Learning Python," 5th Edition, O'Reilly Media, 2013.
