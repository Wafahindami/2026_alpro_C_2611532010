# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Wafa Hindami**
#
# **2611532010**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky yuliandra**
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum pengenalan Python, VS code dan Github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan Pengenalan bahasa pemrograman Python, pemakaian Visual Studio Code sebagai media coding, dan pengaturan koneksi ke akun GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar pemrograman pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi membuat kemampuan pemrograman menjadi salah satu keterampilan yang penting untuk dipelajari. Sebelum mempelajari algoritma dan pembuatan program yang lebih kompleks, mahasiswa perlu mengenal terlebih dahulu bahasa pemrograman dan perangkat yang digunakan dalam proses penulisan kode. Maka perlu dilakukan pengenalan terhadap Python sebagai bahasa pemrograman yang digunakan, mempelajari penggunaan Visual Studio Code sebagai editor untuk menulis dan menjalankan program, dan melakukan konfigurasi Koneksi dengan GitHub untuk menyimpan kode yang dibuat dan menjaga agar walaupun kode tersebut hilang bisa cari di github
# 3 hal dasar ini perlu dipelajari oleh seorang manusia karena ini adalah pondasi penting bagi mahasiswa Informatika
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar sintaks bahasa pemrograman Python, termasuk fungsi cetak (print), komentar, dan karakter *escape*.
# 2. mengetahui cara menginstal, mengatur, dan mengoperasikan Visual Studio Code (VS Code) untuk menulis program.
# 3. Mampu melakukan konfigurasi Git serta mengunggah kode program ke repositori lokal dan GitHub.
# 4. Membuat dan menjalankan program python sederhana
#
# ## 1.3 Manfaat
# 1. Mahasiswa memiliki pemahaman dasar mengenai lingkungan pemrograman.
# 2. Mahasiswa dapat menggunakan Visual Studio Code untuk membuat program Python sederhana.
# 3. Mahasiswa memperoleh pengalaman awal dalam menggunakan GitHub untuk mendukung kegiatan pemrograman.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Dalam praktikum modul pertama ini, terdapat tiga komponen utama yang dipelajari:
#
# 1. **Python**: bahasa pemrograman tingkat tinggi multiguna yang bersifat interpretatif dan mudah dibaca
# 2. **Visual Studio Code (VS Code)**: penyunting kode sumber terbuka dan ringan yang dikembangkan oleh Microsoft untuk sistem operasi multiplatform seperti Windows, macOS, dan Linux, editor ini mendukung beberapa bahasa pemrograman termasuk python melalui instalasi ekstensi
# 3. **GitHub**: platform berbasis cloud yang digunakan untuk menyimpan, mengelola, dan melacak perubahan kode program. Dasar teori GitHub berakar pada konsep Version Control System (VCS) dan penggunaan teknologi Git

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Program1_2611532010"
# Berikut adalah implementasi kode program pertama menggunakan sintaks dasar Python.

# %%
# program pertama
"""
komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print ("hello world")
print()
print("Departemen Informatika")
print ("Universitas Andalas")
print ("/ \\ // \\\\ /// \\\\\\")
print ("program ini" + " dibuat oleh a\n" 
       + "Wafa hindami dan 2611532010")

# %% [markdown]
# hello world
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh a
# Wafa hindami dan 2611532010

# %% [markdown]
# **Penjelasan :**
# 1. **`""" ... """` (Docstring)**: Bagian pertama kode ini menggunakan tanda kutip tiga untuk membuat komentar multi-baris (*multiline comment*). Baris ini tidak akan dieksekusi oleh program dan berfungsi sebagai catatan.
# 2. **`print()`**: Fungsi dasar untuk mencetak teks ke layar. `print()` yang dibiarkan kosong akan mencetak baris kosong (sebagai jarak).
# 3. Karakter Escape `\\`**: Untuk mencetak simbol *backslash* (`\`) di Python, kita harus menggunakan *double backslash* (`\\`) agar tidak dibaca sebagai awalan perintah khusus.
# 4. **Konkatenasi `+` dan `\n`**: Pada baris terakhir, digunakan simbol `+` untuk menggabungkan (*concatenate*) beberapa *string*. Terdapat juga `\n` (newline) yang berfungsi untuk memaksa teks setelahnya turun ke baris baru, sehingga nama Wafa Hindami dicetak di baris bawah.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="Tugas pekan 1.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas1_2611532010"

# %%
# Tugas 1 melakukan program sederhana
print("Hello World")
print("selamat pagi dunia")

print("baris 1 \n baris 2  \n baris 3")

# %% [markdown]
# **Output :**
# Hello World
# selamat pagi dunia
# baris 1
#  baris 2
#  baris 3
#
#
# **Penjelasan :**
# 1. **`print()`**: Fungsi dasar untuk mencetak teks ke layar.
# 2. **Konkatenasi `\n`**: Pada baris terakhir, digunakan `\n` (newline) yang berfungsi untuk memaksa teks setelahnya turun ke baris baru, sehingga Baris 2 dan baris 3 dicetak di baris bawah.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang dapat digunakan untuk mempelajari dasar-dasar pemrograman. Pada praktikum ini dipelajari beberapa sintaks dasar Python seperti `print()`, komentar, penggunaan karakter escape, dan penggabungan string. Dari program yang dibuat, penulis dapat memahami bagaimana perintah-perintah tersebut menghasilkan keluaran pada layar.
#
# Selain mempelajari Python, praktikum ini juga mengenalkan Visual Studio Code sebagai tempat untuk menulis dan menjalankan program serta GitHub sebagai tempat untuk menyimpan dan mengelola kode. Dengan memahami ketiga komponen tersebut, penulis memperoleh dasar untuk melanjutkan pembelajaran algoritma dan pemrograman pada praktikum berikutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “An Informal Introduction to Python,” *Python 3.14.7 Documentation*, 2026. [Online]. Tersedia: https://docs.python.org/3/tutorial/introduction.html. [Diakses 10 September 2026].
#
# [2] Microsoft, “Python in Visual Studio Code,” *Visual Studio Code Documentation*, 2026. [Online]. Tersedia: https://code.visualstudio.com/docs/languages/python. [Diakses 10 September 2026].
#
# [3] GitHub, “About Git,” *GitHub Docs*, 2026. [Online]. Tersedia: https://docs.github.com/en/get-started/using-git/about-git. [Diakses 10 September 2026].
